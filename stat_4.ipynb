# %%
import pandas as pd
import matplotlib.pyplot as plt

s = pd.read_csv('data/stat_4.csv')
plt.plot(s.index.to_numpy(), s.data, ',r', label='ml')
s.describe()
# Out:
#                data
# count  10000.000000
# mean      13.507848
# std        1.441560
# min       11.000200
# 25%       12.260450
# 50%       13.521950
# 75%       14.774975
# max       15.999600
